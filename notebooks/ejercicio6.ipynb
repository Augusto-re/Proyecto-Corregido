# %%
import sys
sys.path.append('../src')

# %%
from utils.constantes import DATASETS_PATH_PROCESSED, DATASETS_PATH_RAW
from utils.config_archivo import get_core_info
from utils.select_dataset import ejecutar_sobre_dataset
from ejercicios import ejercicio6

# %%
# Construir ruta al archivos
datasets_paths = [
    DATASETS_PATH_RAW / 'iadiza',
    DATASETS_PATH_RAW / 'inaturalist',
    DATASETS_PATH_RAW / 'xeno_canto'
]

# %%
# ---------------------Inciso D y E----------------------
ejecutar_sobre_dataset(datasets_paths, ejercicio6.validar_y_crear)
# Out:
# ¿Desea operar sobre un dataset? (s/n):  s
# Seleccione un dataset: A) iadiza, B) inaturalist, C) xeno_canto a
# iadiza
# eliminados: 878
#  porcentaje: 37.0464135021097
#  motivos: {'fecha inválida': 873, 'countryCode vacío': 2, 'registro duplicado': 3}
# ¿Desea operar sobre otro dataset? (s/n):  s
# Seleccione un dataset: A) iadiza, B) inaturalist, C) xeno_canto c
# xeno_canto
# eliminados: 2695
#  porcentaje: 20.005938683097025
#  motivos: {'coordenadas inválidas': 2416, 'fecha inválida': 889, 'longitud inválida': 1, 'latitud inválida': 1, 'registro duplicado': 1}
# ¿Desea operar sobre otro dataset? (s/n):  n

# %%
# ---------------------Inciso A----------------------
ejecutar_sobre_dataset(datasets_paths, ejercicio6.eliminar_registro)
# Out:
# ¿Desea operar sobre un dataset? (s/n):  s
# Seleccione un dataset: A) iadiza, B) inaturalist, C) xeno_canto a
# Ingrese occurrenceID:  6861
# No se encontró el registro IADIZA:COI:006861
# ¿Desea operar sobre otro dataset? (s/n):  s
# Seleccione un dataset: A) iadiza, B) inaturalist, C) xeno_canto a
# Ingrese occurrenceID:  6825
# Se eliminó correctamente el registro IADIZA:COI:006825
# ¿Desea operar sobre otro dataset? (s/n):  n

# %%
###### ---------------------Inciso B----------------------
ejecutar_sobre_dataset(datasets_paths, ejercicio6.eliminar_registro_de_columna)
# Out:
# ¿Desea operar sobre un dataset? (s/n):  s
# Seleccione un dataset: A) iadiza, B) inaturalist, C) xeno_canto a
# Seleccione columna de interés
# 0 - gbifID
# 1 - accessRights
# 2 - bibliographicCitation
# 3 - language
# 4 - license
# 5 - modified
# 6 - publisher
# 7 - references
# 8 - rightsHolder
# 9 - type
# 10 - institutionID
# 11 - collectionID
# 12 - datasetID
# 13 - institutionCode
# 14 - collectionCode
# 15 - datasetName
# 16 - ownerInstitutionCode
# 17 - basisOfRecord
# 18 - informationWithheld
# 19 - dataGeneralizations
# 20 - dynamicProperties
# 21 - occurrenceID
# 22 - catalogNumber
# 23 - recordNumber
# 24 - recordedBy
# 25 - recordedByID
# 26 - individualCount
# 27 - organismQuantity
# 28 - organismQuantityType
# 29 - sex
# 30 - lifeStage
# 31 - reproductiveCondition
# 32 - caste
# 33 - behavior
# 34 - vitality
# 35 - establishmentMeans
# 36 - degreeOfEstablishment
# 37 - pathway
# 38 - georeferenceVerificationStatus
# 39 - occurrenceStatus
# 40 - preparations
# 41 - disposition
# 42 - associatedOccurrences
# 43 - associatedReferences
# 44 - associatedSequences
# 45 - associatedTaxa
# 46 - otherCatalogNumbers
# 47 - occurrenceRemarks
# 48 - organismID
# 49 - organismName
# 50 - organismScope
# 51 - associatedOrganisms
# 52 - previousIdentifications
# 53 - organismRemarks
# 54 - materialEntityID
# 55 - materialEntityRemarks
# 56 - verbatimLabel
# 57 - materialSampleID
# 58 - eventID
# 59 - parentEventID
# 60 - eventType
# 61 - fieldNumber
# 62 - eventDate
# 63 - eventTime
# 64 - startDayOfYear
# 65 - endDayOfYear
# 66 - year
# 67 - month
# 68 - day
# 69 - verbatimEventDate
# 70 - habitat
# 71 - samplingProtocol
# 72 - sampleSizeValue
# 73 - sampleSizeUnit
# 74 - samplingEffort
# 75 - fieldNotes
# 76 - eventRemarks
# 77 - locationID
# 78 - higherGeographyID
# 79 - higherGeography
# 80 - continent
# 81 - waterBody
# 82 - islandGroup
# 83 - island
# 84 - countryCode
# 85 - stateProvince
# 86 - county
# 87 - municipality
# 88 - locality
# 89 - verbatimLocality
# 90 - verbatimElevation
# 91 - verticalDatum
# 92 - verbatimDepth
# 93 - minimumDistanceAboveSurfaceInMeters
# 94 - maximumDistanceAboveSurfaceInMeters
# 95 - locationAccordingTo
# 96 - locationRemarks
# 97 - decimalLatitude
# 98 - decimalLongitude
# 99 - coordinateUncertaintyInMeters
# 100 - coordinatePrecision
# 101 - pointRadiusSpatialFit
# 102 - verbatimCoordinateSystem
# 103 - verbatimSRS
# 104 - footprintWKT
# 105 - footprintSRS
# 106 - footprintSpatialFit
# 107 - georeferencedBy
# 108 - georeferencedDate
# 109 - georeferenceProtocol
# 110 - georeferenceSources
# 111 - georeferenceRemarks
# 112 - geologicalContextID
# 113 - earliestEonOrLowestEonothem
# 114 - latestEonOrHighestEonothem
# 115 - earliestEraOrLowestErathem
# 116 - latestEraOrHighestErathem
# 117 - earliestPeriodOrLowestSystem
# 118 - latestPeriodOrHighestSystem
# 119 - earliestEpochOrLowestSeries
# 120 - latestEpochOrHighestSeries
# 121 - earliestAgeOrLowestStage
# 122 - latestAgeOrHighestStage
# 123 - lowestBiostratigraphicZone
# 124 - highestBiostratigraphicZone
# 125 - lithostratigraphicTerms
# 126 - group
# 127 - formation
# 128 - member
# 129 - bed
# 130 - identificationID
# 131 - verbatimIdentification
# 132 - identificationQualifier
# 133 - typeStatus
# 134 - identifiedBy
# 135 - identifiedByID
# 136 - dateIdentified
# 137 - identificationReferences
# 138 - identificationVerificationStatus
# 139 - identificationRemarks
# 140 - taxonID
# 141 - scientificNameID
# 142 - acceptedNameUsageID
# 143 - parentNameUsageID
# 144 - originalNameUsageID
# 145 - nameAccordingToID
# 146 - namePublishedInID
# 147 - taxonConceptID
# 148 - scientificName
# 149 - acceptedNameUsage
# 150 - parentNameUsage
# 151 - originalNameUsage
# 152 - nameAccordingTo
# 153 - namePublishedIn
# 154 - namePublishedInYear
# 155 - higherClassification
# 156 - kingdom
# 157 - phylum
# 158 - class
# 159 - order
# 160 - superfamily
# 161 - family
# 162 - subfamily
# 163 - tribe
# 164 - subtribe
# 165 - genus
# 166 - genericName
# 167 - subgenus
# 168 - infragenericEpithet
# 169 - specificEpithet
# 170 - infraspecificEpithet
# 171 - cultivarEpithet
# 172 - taxonRank
# 173 - verbatimTaxonRank
# 174 - vernacularName
# 175 - nomenclaturalCode
# 176 - taxonomicStatus
# 177 - nomenclaturalStatus
# 178 - taxonRemarks
# 179 - datasetKey
# 180 - publishingCountry
# 181 - lastInterpreted
# 182 - elevation
# 183 - elevationAccuracy
# 184 - depth
# 185 - depthAccuracy
# 186 - distanceFromCentroidInMeters
# 187 - issue
# 188 - taxonomicIssue
# 189 - nonTaxonomicIssue
# 190 - mediaType
# 191 - hasCoordinate
# 192 - hasGeospatialIssues
# 193 - taxonKey
# 194 - acceptedTaxonKey
# 195 - kingdomKey
# 196 - phylumKey
# 197 - classKey
# 198 - orderKey
# 199 - superfamilyKey
# 200 - familyKey
# 201 - subfamilyKey
# 202 - tribeKey
# 203 - subtribeKey
# 204 - genusKey
# 205 - subgenusKey
# 206 - speciesKey
# 207 - species
# 208 - acceptedScientificName
# 209 - verbatimScientificName
# 210 - typifiedName
# 211 - protocol
# 212 - lastParsed
# 213 - lastCrawled
# 214 - isInvasive
# 215 - repatriated
# 216 - relativeOrganismQuantity
# 217 - projectId
# 218 - isSequenced
# 219 - gbifRegion
# 220 - publishedByGbifRegion
# 221 - level0Gid
# 222 - level0Name
# 223 - level1Gid
# 224 - level1Name
# 225 - level2Gid
# 226 - level2Name
# 227 - level3Gid
# 228 - level3Name
# 229 - iucnRedListCategory
# Seleccionar:  24
# Ingrese valores a eliminar (exit para terminar):
#  Julio Rafael Contreras Roqué
#  exit
# No se eliminaron registros

# %%
# ---------------------Inciso C----------------------
ejecutar_sobre_dataset(datasets_paths, ejercicio6.eliminar_multiples_columnas_valores)
# Out:
# ¿Desea operar sobre un dataset? (s/n):  s
# Seleccione un dataset: A) iadiza, B) inaturalist, C) xeno_canto b
# Seleccione columnas de interés
# 0 - id
# 1 - occurrenceID
# 2 - basisOfRecord
# 3 - modified
# 4 - institutionCode
# 5 - collectionCode
# 6 - datasetName
# 7 - informationWithheld
# 8 - catalogNumber
# 9 - references
# 10 - occurrenceRemarks
# 11 - recordedBy
# 12 - recordedByID
# 13 - identifiedBy
# 14 - identifiedByID
# 15 - captive
# 16 - eventDate
# 17 - eventTime
# 18 - verbatimEventDate
# 19 - verbatimLocality
# 20 - decimalLatitude
# 21 - decimalLongitude
# 22 - coordinateUncertaintyInMeters
# 23 - geodeticDatum
# 24 - countryCode
# 25 - stateProvince
# 26 - identificationID
# 27 - dateIdentified
# 28 - identificationRemarks
# 29 - taxonID
# 30 - scientificName
# 31 - taxonRank
# 32 - kingdom
# 33 - phylum
# 34 - class
# 35 - order
# 36 - family
# 37 - genus
# 38 - license
# 39 - rightsHolder
# 40 - inaturalistLogin
# 41 - publishingCountry
# 42 - projectId
# 43 - sex
# 44 - lifeStage
# 45 - reproductiveCondition
# 46 - vitality
# 47 - dynamicProperties
# Ingrese índices (-1 para terminar):
# Seleccionar:  0
# Seleccionar:  11
# Seleccionar:  -1
# Ingrese valores para la columna 'id' (exit para terminar):
#  42369866
#  42369871
#  42369872
#  exit
# Ingrese valores para la columna 'recordedBy' (exit para terminar):
#  demianlescano
#  pablo h capovilla
#  exit
